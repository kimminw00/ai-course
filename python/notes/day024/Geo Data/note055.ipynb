# %%
# !pip install pdvega

# %%
import numpy as np
import pandas as pd
import pdvega

# %%
import seaborn as sns

# %%
df = pd.DataFrame({'x': np.random.randn(100), 'y': np.random.randn(100)})
df.plot.scatter(x='x', y='y')
df.vgplot.scatter(x='x', y='y')

# view source로 json파일 얻음
# Out:
# /Users/joey/anaconda3/lib/python3.7/site-packages/pdvega/_core.py:473: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   "type": infer_vegalite_type(data[x], ordinal_threshold=0)
# /Users/joey/anaconda3/lib/python3.7/site-packages/pdvega/_core.py:477: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   "type": infer_vegalite_type(data[y], ordinal_threshold=0)
# <div class="vega-embed" id="64ecd119-21ce-4341-aec7-577180459764"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# ...
