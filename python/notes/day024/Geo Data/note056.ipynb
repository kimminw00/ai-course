# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_json('asset/seoul_municipalities_geo_simple.json')

# %%
data
# 데이터가 너무 장황하다(필요 이상)... 내가 원하는 특정 데이터만 뽑아내고 싶다.
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 5   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 6   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 7   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 8   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 9   FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 10  FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# 11  FeatureCollection  {'type': 'Feature', 'properties': {'code': '11...
# ...

# %%
# open명령어로는 우리가 불러올 수 있는 것은 plat file만...!

# %%
data = pd.read_json('asset/seoul_municipalities_topo_simple.json') # 구 별로 쪼개서 보여주는 데이터
# 너무 복잡한 형태면 pandas가 읽지를 못함
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-da49b5fb8c44> in <module>
# ----> 1 data = pd.read_json('asset/seoul_municipalities_topo_simple.json') # 구 별로 쪼개서 보여주는 데이터
#       2 # 너무 복잡한 형태면 pandas가 읽지를 못함
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ...

# %%
with open('asset/seoul_municipalities_topo_simple.json') as f:
    print(f.read()) # 단점 : str형태로 읽어들임, 객체의 의미를 잃어버림...
    # jason 하고 csv일 때는 pickle을 사용안하고 다른 방식으로 읽어들인다. json.load, csv.reader로 읽어들이면 된다.
    # 객체의 의미를 잃어버리지 않고 읽어들이는 방법 : json.load, csv.reader
# Out:
# {"type":"Topology","transform":{"scale":[0.00006247075827918093,0.00005151814945568312],"translate":[126.76700465024426,37.42574929824175]},"objects":{"seoul_municipalities_geo":{"type":"GeometryCollection","geometries":[{"arcs":[[0,1,2]],"type":"Polygon","properties":{"code":"11250","name":"강동구","name_eng":"Gangdong-gu","base_year":"2013"}},{"arcs":[[3,-2,4,5]],"type":"Polygon","properties":{"code":"11240","name":"송파구","name_eng":"Songpa-gu","base_year":"2013"}},{"arcs":[[6,-6,7,8,9,10]],"type":"Polygon","properties":{"code":"11230","name":"강남구","name_eng":"Gangnam-gu","base_year":"2013"}},{"arcs":[[-9,11,12,13,14]],"type":"Polygon","properties":{"code":"11220","name":"서초구","name_eng":"Seocho-gu","base_year":"2013"}},{"arcs":[[-13,15,16,17,18]],"type":"Polygon","properties":{"code":"11210","name":"관악구","name_eng":"Gwanak-gu","base_year":"2013"}},{"arcs":[[-14,-19,19,20]],"type":"Polygon","properties":{"code":"11200","name":"동작구","name_eng":"Dongjak-gu","base_year":"2013"}},{"arcs":[
# ...

# %%
import json

# %%
with open('asset/seoul_municipalities_topo_simple.json', encoding='utf-8') as f:
    x = json.load(f) # 불러들인 파일을 jason으로 만듦

# %%
x
# 구조를 알아보기 힘들다....
# Out:
# {'type': 'Topology',
#  'transform': {'scale': [6.247075827918093e-05, 5.151814945568312e-05],
#   'translate': [126.76700465024426, 37.42574929824175]},
#  'objects': {'seoul_municipalities_geo': {'type': 'GeometryCollection',
#    'geometries': [{'arcs': [[0, 1, 2]],
#      'type': 'Polygon',
#      'properties': {'code': '11250',
#       'name': '강동구',
#       'name_eng': 'Gangdong-gu',
#       'base_year': '2013'}},
#     {'arcs': [[3, -2, 4, 5]],
#      'type': 'Polygon',
#      'properties': {'code': '11240',
#       'name': '송파구',
#       'name_eng': 'Songpa-gu',
#       'base_year': '2013'}},
#     {'arcs': [[6, -6, 7, 8, 9, 10]],
#      'type': 'Polygon',
#      'properties': {'code': '11230',
#       'name': '강남구',
#       'name_eng': 'Gangnam-gu',
#       'base_year': '2013'}},
#     {'arcs': [[-9, 11, 12, 13, 14]],
#      'type': 'Polygon',
#      'properties': {'code': '11220',
#       'name': '서초구',
#       'name_eng': 'Seocho-gu',
#       'base_year': '2013'}},
# ...

# %%
x['type']
# dictionary처럼 사용 가능
# Out:
# 'Topology'

# %%
x['objects']['seoul_municipalities_geo']
# 이건 dict
# Out:
# {'type': 'GeometryCollection',
#  'geometries': [{'arcs': [[0, 1, 2]],
#    'type': 'Polygon',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'}},
#   {'arcs': [[3, -2, 4, 5]],
#    'type': 'Polygon',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'}},
#   {'arcs': [[6, -6, 7, 8, 9, 10]],
#    'type': 'Polygon',
#    'properties': {'code': '11230',
#     'name': '강남구',
#     'name_eng': 'Gangnam-gu',
#     'base_year': '2013'}},
#   {'arcs': [[-9, 11, 12, 13, 14]],
#    'type': 'Polygon',
#    'properties': {'code': '11220',
#     'name': '서초구',
#     'name_eng': 'Seocho-gu',
#     'base_year': '2013'}},
#   {'arcs': [[-13, 15, 16, 17, 18]],
#    'type': 'Polygon',
#    'properties': {'code': '11210',
#     'name': '관악구',
#     'name_eng': 'Gwanak-gu',
#     'base_year': '2013'}},
#   {'arcs': [[-14, -19, 19, 20]],
#    'type': 'Polygon',
# ...

# %%
x['objects']['seoul_municipalities_geo']['geometries']
# 이건 list
# Out:
# [{'arcs': [[0, 1, 2]],
#   'type': 'Polygon',
#   'properties': {'code': '11250',
#    'name': '강동구',
#    'name_eng': 'Gangdong-gu',
#    'base_year': '2013'}},
#  {'arcs': [[3, -2, 4, 5]],
#   'type': 'Polygon',
#   'properties': {'code': '11240',
#    'name': '송파구',
#    'name_eng': 'Songpa-gu',
#    'base_year': '2013'}},
#  {'arcs': [[6, -6, 7, 8, 9, 10]],
#   'type': 'Polygon',
#   'properties': {'code': '11230',
#    'name': '강남구',
#    'name_eng': 'Gangnam-gu',
#    'base_year': '2013'}},
#  {'arcs': [[-9, 11, 12, 13, 14]],
#   'type': 'Polygon',
#   'properties': {'code': '11220',
#    'name': '서초구',
#    'name_eng': 'Seocho-gu',
#    'base_year': '2013'}},
#  {'arcs': [[-13, 15, 16, 17, 18]],
#   'type': 'Polygon',
#   'properties': {'code': '11210',
#    'name': '관악구',
#    'name_eng': 'Gwanak-gu',
#    'base_year': '2013'}},
#  {'arcs': [[-14, -19, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'code': '11200',
#    'name': '동작구',
#    'name_eng': 'Dongjak-gu',
# ...

# %%
from pprint import pprint
# 예쁘게 출력하는 방법

# %%
pprint(x)
# 사람들 보기 좋게 indent를 해준다.
# Out:
# {'arcs': [[[5574, 2558],
#            [57, -6],
#            [43, 51],
#            [46, 31],
#            [186, 82],
#            [214, 63],
#            [93, 39],
#            [187, 113],
#            [57, -6],
#            [91, 7],
#            [48, 22],
#            [-25, -67],
#            [11, -58],
#            [28, -42],
#            [21, -58],
#            [7, -68],
#            [38, -91],
#            [-9, -157],
#            [28, -23],
#            [-7, -70],
#            [10, -52],
#            [-29, -3],
#            [-39, 27],
#            [-56, -27],
#            [-52, 7],
#            [-98, -26],
#            [-48, 15],
#            [-154, -214],
#            [-5, -91],
#            [-62, -72],
#            [-27, -69],
#            [-31, -1],
#            [-17, -50],
#            [-2, -48]],
#           [[6078, 1716],
#            [-22, 9],
#            [-386, 207],
#            [21, 43],
#            [45, 160],
#            [-76, 46],
#            [-143, 50]],
# ...
